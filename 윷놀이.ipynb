# %%
import random

point = random.randint(1,5)

my_score = 0
enemy_score = 0


while  my_score <30 and enemy_score <30:
    
    while True:#내 턴
        print('>>>당신이 윷을 던졌습니다!')
        point = random.randint(1,5)
        
        if point == 1:
            my_score+=1
            
            print("도! 1점을 획득하여 현재 당신의 점수는 {0}점입니다.".format(my_score))
            if my_score <30:
                print("다음은 상대방의 차례입니다.")
                break
            
            break
        elif point == 2:
            my_score+=2
            
            print("개! 2점을 획득하여 현재 당신의 점수는 {0}점입니다.".format(my_score))
            if my_score <30:
                print("다음은 상대방의 차례입니다.")
                break
            
            break
        elif point == 3:
            my_score+=3
            
            print("걸! 3점을 획득하여 현재 당신의 점수는 {0}점입니다.".format(my_score))
            if my_score < 30:
                print("다음은 상대방의 차례입니다.")
                break
            
            break
        elif point == 4:
            my_score+=4
            
            print("윷! 4점을 획득하여 현재 당신의 점수는 {0}점입니다.".format(my_score))
            if my_score <30:
                print("당신에게 한번 더 던질 기회가 주어집니다.")
                continue
            
            break
        elif point == 5:
            my_score+=5
            
            print("모! 5점을 획득하여 현재 당신의 점수는 {0}점입니다.".format(my_score))
            if my_score <30:
                print("당신에게 한번 더 던질 기회가 주어집니다.")
                continue
            
            break
    
    if my_score >=30:
        break
        
    while True:
        print('>>>상대방이 윷을 던졌습니다!')
        point = random.randint(1,5)
        
        if point == 1:
            enemy_score+=1
            
            print("도! 1점을 획득하여 현재 상대방의 점수는 {0}점입니다.".format(enemy_score))
            if enemy_score < 30:
                print("다음은 당신의 차례입니다.")
                break
            
            break
        elif point == 2:
            enemy_score+=2
            
            print("개! 2점을 획득하여 현재 상대방의 점수는 {0}점입니다.".format(enemy_score))
            if enemy_score < 30:
                print("다음은 당신의 차례입니다.")
                break
            
            
            break
        elif point == 3:
            enemy_score+=3
            
            print("걸! 3점을 획득하여 현재 상대방의 점수는 {0}점입니다.".format(enemy_score))
            if enemy_score < 30:
                print("다음은 당신의 차례입니다.")
                break
            
            break
        elif point == 4:
            enemy_score+=4
            
            print("윷! 4점을 획득하여 현재 상대방의 점수는 {0}점입니다.".format(enemy_score))
            if enemy_score < 30:
                print('상대방에게 한번 더 던질 기회가 주어집니다.')
                continue
            
            break
        elif point == 5:
            enemy_score+=5
            
            print("모! 5점을 획득하여 현재 상대방의 점수는 {0}점입니다.".format(enemy_score))
            if enemy_score < 30:  
                print('상대방에게 한번 더 던질 기회가 주어집니다.')
                continue
            
            break
    
    if enemy_score >=30:
        break
            
        

if (my_score >=30):
    print(">>>당신이 승리했습니다. 당신의 점수: {0}, 상대방의 점수: {1}".format(my_score,enemy_score))
    
else:
    print(">>>당신이 패배했습니다. 상대방의 점수: {0}, 당신의 점수: {1}".format(enemy_score,my_score))
# Out:
# >>>당신이 윷을 던졌습니다!
# 윷! 4점을 획득하여 현재 당신의 점수는 4점입니다.
# 당신에게 한번 더 던질 기회가 주어집니다.
# >>>당신이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 당신의 점수는 7점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 윷! 4점을 획득하여 현재 상대방의 점수는 4점입니다.
# 상대방에게 한번 더 던질 기회가 주어집니다.
# >>>상대방이 윷을 던졌습니다!
# 개! 2점을 획득하여 현재 상대방의 점수는 6점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 당신의 점수는 10점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 윷! 4점을 획득하여 현재 상대방의 점수는 10점입니다.
# 상대방에게 한번 더 던질 기회가 주어집니다.
# >>>상대방이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 상대방의 점수는 13점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 당신의 점수는 13점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 도! 1점을 획득하여 현재 상대방의 점수는 14점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 당신의 점수는 16점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 개! 2점을 획득하여 현재 상대방의 점수는 16점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 모! 5점을 획득하여 현재 당신의 점수는 21점입니다.
# 당신에게 한번 더 던질 기회가 주어집니다.
# >>>당신이 윷을 던졌습니다!
# 도! 1점을 획득하여 현재 당신의 점수는 22점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 윷! 4점을 획득하여 현재 상대방의 점수는 20점입니다.
# 상대방에게 한번 더 던질 기회가 주어집니다.
# >>>상대방이 윷을 던졌습니다!
# 도! 1점을 획득하여 현재 상대방의 점수는 21점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 개! 2점을 획득하여 현재 당신의 점수는 24점입니다.
# 다음은 상대방의 차례입니다.
# >>>상대방이 윷을 던졌습니다!
# 도! 1점을 획득하여 현재 상대방의 점수는 22점입니다.
# 다음은 당신의 차례입니다.
# >>>당신이 윷을 던졌습니다!
# 윷! 4점을 획득하여 현재 당신의 점수는 28점입니다.
# 당신에게 한번 더 던질 기회가 주어집니다.
# >>>당신이 윷을 던졌습니다!
# 걸! 3점을 획득하여 현재 당신의 점수는 31점입니다.
# 당신이 승리했습니다. 당신의 점수: 31, 상대방의 점수: 22
